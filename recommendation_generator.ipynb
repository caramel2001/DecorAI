# %%
import base64
import requests
from dotenv import load_dotenv
load_dotenv()
import os
# OpenAI API Key
api_key = os.getenv("OPENAI_API_KEY")
import json
user_pref = None
with open('survey_results.json', 'r') as f:
    user_pref = json.load(f)


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "images/empty_room.png"

# Getting the base64 string
base64_image = encode_image(image_path)
print(base64_image)


headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}",
    "response_format": "json",

}

payload = {
  "model": "gpt-4-vision-preview",
  "messages": [
    {
      "role": "system",
      "content": "You are a highly skilled interior designer and prompt engineer with a keen eye for detail. Your expertise lies in analyzing images of rooms, identifying areas that can be enhanced, and recommending products to improve the overall aesthetic and functionality of the space. Your analysis is thorough, considering each section and wall of the room meticulously to ensure no detail is overlooked."
    },
    {
      "role": "user",
      "content": [{
        "type": "text",
        "text": f"# CONTEXT #\n As an interior designer, you are tasked with providing ideas and product recommendations to enhance rooms based on images provided by users.\n\n# OBJECTIVE #\nAnalyze the provided image of a room. Examine the space section by section and wall by wall, meticulously identifying opportunities for improvement. Suggest 4 products that can enhance the room's appearance and functionality, including specific measurements and materials for each product also keep in mind user preferences {user_pref}. Focus on creating a  appealing environment . If the room is empty then recommend the essentials for the particular room . provide a prompt which describes the products properly with positions measurements and all the necessary information so that a fill anything model can add it in , include coordinates and positions or any other way so that i can generate mask so that i can inpaint the image  So the most important thing is generate a prompt that can allow a stable diffusion model to generate an image with the necessary products and materials ensure the prompt uses simple words and is only 80 tokens long please generate a efficent prompt or you will get fired from your job.  \n\n# PROMPT #\n"
      }]
    },
    {
      "role": "user",
      "content": [{
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpg;base64,{base64_image}"
        }
      }]
    }
  ],
  "max_tokens": 1500
}



response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

response = response.json()
# Out:
# ...

# %%
products = response['choices'][0]['message']['content']
print(products)
# Out:
# Pastel-themed room: white wall, carpet floor, bed centerpiece, natural light. Add plush bedding, sheer curtains, wall-mounted shelves, ergonomic desk chair.

# %%
# pretty print the products
# Out:
# {
#   "product": "Modern Desk Chair",
#   "description": "A sleek, ergonomic chair to replace the existing one, providing better support and adding to the room’s modern aesthetic.",
#   "measurements": "Seat height: 17-21 inches, Width and depth: 18 inches",
#   "materials": "Leather upholstery, metal base, foam cushioning",
#   "prompt": "Replace the existing desk chair positioned in front of the desk at coordinates (300, 450) with a modern desk chair with the provided measurements and materials."
# },
# {
#   "product": "Area Rug",
#   "description": "A contemporary area rug to inject warmth and texture into the space, creating a cozy atmosphere.",
#   "measurements": "8' x 10'",
#   "materials": "Wool or high-quality synthetic blend",
#   "prompt": "Center a contemporary 8' x 10' area rug in the open floor space at coordinates (250, 600), ensuring it flows under the bed and desk area for a cohesive look."
# },
# {
#   "product": "Wall Art",
#   "description": "Large canvas prints or framed artwork to fill the empty wall space, providing visual interest and personality.",
#   "measurements": "24' x 36'",
#   "materials": "Canvas or high-resolution print within a minimalistic frame",
#   "prompt": "Place a 24' x 36' piece of framed artwork on the wall space directly above the desk at coordinates (700, 150) to create a focal point."
# },
# {
#   "product": "Window Treatments",
#   "description": "Modern blackout curtains paired with sheer drapes for layered window treatments, offering light control and visual depth.",
#   "measurements": "To fit window size, typically 84' length",
#   "materials": "Blackout fabric for the back layer, light sheer fabric for the front",
#   "prompt": "Hang blackout curtains behind the existing curtain rod at coordinates (50, 50) and sheer drapes in front to enhance the window, using the aforementioned materials and measurements."
# },
# {
#   "product": "Storage Cabinet",
#   "description": "A multi-purpose storage cabinet to the right of the desk for organizing and de-cluttering the space, maximizing functionality.",
#   "measurements": "Height: 72 inches, Width: 24 inches, Depth: 15 inches",
#   "materials": "Wood or high-density fiberboard with a matte finish",
#   "prompt": "Replace the existing black storage unit at coordinates (900, 350) with a taller storage cabinet with doors, following the provided measurements and material."
# },
# {
#   "product": "Bedding Set",
#   "description": "A modern, neutral-colored bedding set to replace the current one for a more sophisticated and cohesive bedroom look.",
#   "measurements": "Size to fit existing bed dimensions, typically Queen or Full",
#   "materials": "Cotton or linen set with duvet cover and pillowcases",
#   "prompt": "Apply a new bedding set on the bed positioned at coordinates (100, 300), choosing materials and sizes according to the existing bed."
# }
#
# Note: The coordinates provided in the prompts are hypothetical and should be adjusted according to the real position measurements in the image. The "prompt" suggestions are aligned with the expected masks for inpainting and are meant to guide the placement of items within the space for a clear and concise design vision.

# %%
response
